# %% [markdown]
# # Neural Style Transfer

# %%
 '''Neural style transfer with Keras.
Run the script with:
```
python neural_style_transfer.py path_to_your_base_image.jpg \
    path_to_your_reference.jpg prefix_for_results
```
e.g.:
```
```
--iter, To specify the number of iterations \
    the style transfer takes place (Default is 10)
--content_weight, The weight given to the content loss (Default is 0.025)
--style_weight, The weight given to the style loss (Default is 1.0)
--tv_weight, The weight given to the total variation loss (Default is 1.0)
```
It is preferable to run this script on GPU, for speed.
Example result: https://twitter.com/fchollet/status/686631033085677568
# Details
Style transfer consists in generating an image
with the same "content" as a base image, but with the
"style" of a different picture (typically artistic).
This is achieved through the optimization of a loss function
that has 3 components: "style loss", "content loss",
and "total variation loss":
- The total variation loss imposes local spatial continuity between
the pixels of the combination image, giving it visual coherence.
- The style loss is where the deep learning keeps in --that one is defined
using a deep convolutional neural network. Precisely, it consists in a sum of
L2 distances between the Gram matrices of the representations of
the base image and the style reference image, extracted from
different layers of a convnet (trained on ImageNet). The general idea
is to capture color/texture information at different spatial
scales (fairly large scales --defined by the depth of the layer considered).
 - The content loss is a L2 distance between the features of the base
image (extracted from a deep layer) and the features of the combination image,
keeping the generated image close enough to the original one.
# References
    - [A Neural Algorithm of Artistic Style](http://arxiv.org/abs/1508.06576)
'''

from __future__ import print_function
from keras.preprocessing.image import load_img, save_img, img_to_array
import numpy as np
from scipy.optimize import fmin_l_bfgs_b
import time
import argparse

from keras.applications import vgg19
from keras import backend as K

base_image_path = ('c3.jpg')
style_reference_image_path = ('5.jpg')
result_prefix = ('qp')
iterations = 200

# these are the weights of the different loss components
total_variation_weight = 1.0
style_weight = 1.0
content_weight = 0.025

# dimensions of the generated picture.
width, height = load_img(base_image_path).size
img_nrows = 400
img_ncols = int(width * img_nrows / height)

# util function to open, resize and format pictures into appropriate tensors


def preprocess_image(image_path):
    img = load_img(image_path, target_size=(img_nrows, img_ncols))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg19.preprocess_input(img)
    return img

# util function to convert a tensor into a valid image


def deprocess_image(x):
    if K.image_data_format() == 'channels_first':
        x = x.reshape((3, img_nrows, img_ncols))
        x = x.transpose((1, 2, 0))
    else:
        x = x.reshape((img_nrows, img_ncols, 3))
    # Remove zero-center by mean pixel
    x[:, :, 0] = x[:, :, 0] + 103.939
    x[:, :, 1] = x[:, :, 1] + 116.779
    x[:, :, 2] = x[:, :, 2] + 123.68
    # 'BGR'->'RGB'
    x = x[:, :, ::-1]
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# get tensor representations of our images
base_image = K.variable(preprocess_image(base_image_path))
style_reference_image = K.variable(preprocess_image(style_reference_image_path))

# this will contain our generated image
if K.image_data_format() == 'channels_first':
    combination_image = K.placeholder((1, 3, img_nrows, img_ncols))
else:
    combination_image = K.placeholder((1, img_nrows, img_ncols, 3))

# combine the 3 images into a single Keras tensor
input_tensor = K.concatenate([base_image,
                              style_reference_image,
                              combination_image], axis=0)

# build the VGG19 network with our 3 images as input
# the model will be loaded with pre-trained ImageNet weights
model = vgg19.VGG19(input_tensor=input_tensor,
                    weights='imagenet', include_top=False)
print('Model loaded.')

# get the symbolic outputs of each "key" layer (we gave them unique names).
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])

# compute the neural style loss
# first we need to define 4 util functions

# the gram matrix of an image tensor (feature-wise outer product)


def gram_matrix(x):
    assert K.ndim(x) == 3
    if K.image_data_format() == 'channels_first':
        features = K.batch_flatten(x)
    else:
        features = K.batch_flatten(K.permute_dimensions(x, (2, 0, 1)))
    gram = K.dot(features, K.transpose(features))
    return gram

# the "style loss" is designed to maintain
# the style of the reference image in the generated image.
# It is based on the gram matrices (which capture style) of
# feature maps from the style reference image
# and from the generated image


def style_loss(style, combination):
    assert K.ndim(style) == 3
    assert K.ndim(combination) == 3
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    size = img_nrows * img_ncols
    return K.sum(K.square(S - C)) / (4.0 * (channels ** 2) * (size ** 2))

# an auxiliary loss function
# designed to maintain the "content" of the
# base image in the generated image


def content_loss(base, combination):
    return K.sum(K.square(combination - base))

# the 3rd loss function, total variation loss,
# designed to keep the generated image locally coherent


def total_variation_loss(x):
    assert K.ndim(x) == 4
    if K.image_data_format() == 'channels_first':
        a = K.square(
            x[:, :, :img_nrows - 1, :img_ncols - 1] - x[:, :, 1:, :img_ncols - 1])
        b = K.square(
            x[:, :, :img_nrows - 1, :img_ncols - 1] - x[:, :, :img_nrows - 1, 1:])
    else:
        a = K.square(
            x[:, :img_nrows - 1, :img_ncols - 1, :] - x[:, 1:, :img_ncols - 1, :])
        b = K.square(
            x[:, :img_nrows - 1, :img_ncols - 1, :] - x[:, :img_nrows - 1, 1:, :])
    return K.sum(K.pow(a + b, 1.25))

# combine these loss functions into a single scalar
loss = K.variable(0.0)
layer_features = outputs_dict['block5_conv2']
base_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]
loss = loss + content_weight * content_loss(base_image_features,
                                      combination_features)

feature_layers = ['block1_conv1', 'block2_conv1',
                  'block3_conv1', 'block4_conv1',
                  'block5_conv1']
for layer_name in feature_layers:
    layer_features = outputs_dict[layer_name]
    style_reference_features = layer_features[1, :, :, :]
    combination_features = layer_features[2, :, :, :]
    sl = style_loss(style_reference_features, combination_features)
    loss = loss + (style_weight / len(feature_layers)) * sl
loss = loss + total_variation_weight * total_variation_loss(combination_image)

# get the gradients of the generated image wrt the loss
grads = K.gradients(loss, combination_image)

outputs = [loss]
if isinstance(grads, (list, tuple)):
    outputs =outputs + grads
else:
    outputs.append(grads)

f_outputs = K.function([combination_image], outputs)


def eval_loss_and_grads(x):
    if K.image_data_format() == 'channels_first':
        x = x.reshape((1, 3, img_nrows, img_ncols))
    else:
        x = x.reshape((1, img_nrows, img_ncols, 3))
    outs = f_outputs([x])
    loss_value = outs[0]
    if len(outs[1:]) == 1:
        grad_values = outs[1].flatten().astype('float64')
    else:
        grad_values = np.array(outs[1:]).flatten().astype('float64')
    return loss_value, grad_values

# this Evaluator class makes it possible
# to compute loss and gradients in one pass
# while retrieving them via two separate functions,
# "loss" and "grads". This is done because scipy.optimize
# requires separate functions for loss and gradients,
# but computing them separately would be inefficient.


class Evaluator(object):

    def __init__(self):
        self.loss_value = None
        self.grads_values = None

    def loss(self, x):
        assert self.loss_value is None
        loss_value, grad_values = eval_loss_and_grads(x)
        self.loss_value = loss_value
        self.grad_values = grad_values
        return self.loss_value

    def grads(self, x):
        assert self.loss_value is not None
        grad_values = np.copy(self.grad_values)
        self.loss_value = None
        self.grad_values = None
        return grad_values

evaluator = Evaluator()

# run scipy-based optimization (L-BFGS) over the pixels of the generated image
# so as to minimize the neural style loss
x = preprocess_image(base_image_path)

for i in range(iterations):
    print('Start of iteration', i)
    start_time = time.time()
    x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x.flatten(),
                                     fprime=evaluator.grads, maxfun=20)
    print('Current loss value:', min_val)
    # save current generated image
    img = deprocess_image(x.copy())
    fname = result_prefix + '_at_iteration_%d.png' % i
    save_img(fname, img)
    end_time = time.time()
    print('Image saved as', fname)
    print('Iteration %d completed in %ds' % (i, end_time - start_time))
# Out:
# Using TensorFlow backend.
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step
# Model loaded.
# Start of iteration 0
# Current loss value: 3722763300.0
# Image saved as v_at_iteration_0.png
# Iteration 0 completed in 25s
# Start of iteration 1
# Current loss value: 2486828000.0
# Image saved as v_at_iteration_1.png
# Iteration 1 completed in 18s
# Start of iteration 2
# Current loss value: 2148441600.0
# Image saved as v_at_iteration_2.png
# Iteration 2 completed in 18s
# Start of iteration 3
# Current loss value: 2017080800.0
# Image saved as v_at_iteration_3.png
# Iteration 3 completed in 18s
# Start of iteration 4
# Current loss value: 1925689900.0
# Image saved as v_at_iteration_4.png
# Iteration 4 completed in 18s
# Start of iteration 5
# Current loss value: 1868984800.0
# Image saved as v_at_iteration_5.png
# Iteration 5 completed in 18s
# Start of iteration 6
# Current loss value: 1832544800.0
# Image saved as v_at_iteration_6.png
# Iteration 6 completed in 18s
# Start of iteration 7
# Current loss value: 1804979500.0
# Image saved as v_at_iteration_7.png
# Iteration 7 completed in 18s
# Start of iteration 8
# Current loss value: 1778774800.0
# Image saved as v_at_iteration_8.png
# Iteration 8 completed in 18s
# Start of iteration 9
# Current loss value: 1761870100.0
# Image saved as v_at_iteration_9.png
# Iteration 9 completed in 18s
# Start of iteration 10
# Current loss value: 1749012700.0
# Image saved as v_at_iteration_10.png
# Iteration 10 completed in 18s
# Start of iteration 11
# Current loss value: 1735674900.0
# Image saved as v_at_iteration_11.png
# Iteration 11 completed in 18s
# Start of iteration 12
# Current loss value: 1725800000.0
# Image saved as v_at_iteration_12.png
# Iteration 12 completed in 18s
# Start of iteration 13
# Current loss value: 1717473500.0
# Image saved as v_at_iteration_13.png
# Iteration 13 completed in 18s
# Start of iteration 14
# Current loss value: 1708460300.0
# Image saved as v_at_iteration_14.png
# Iteration 14 completed in 18s
# Start of iteration 15
# Current loss value: 1701172700.0
# Image saved as v_at_iteration_15.png
# Iteration 15 completed in 18s
# Start of iteration 16
# Current loss value: 1694811400.0
# Image saved as v_at_iteration_16.png
# Iteration 16 completed in 18s
# Start of iteration 17
# Current loss value: 1687851100.0
# Image saved as v_at_iteration_17.png
# Iteration 17 completed in 18s
# Start of iteration 18
# Current loss value: 1682064400.0
# Image saved as v_at_iteration_18.png
# Iteration 18 completed in 18s
# Start of iteration 19
# Current loss value: 1677246800.0
# Image saved as v_at_iteration_19.png
# Iteration 19 completed in 18s
# Start of iteration 20
# Current loss value: 1672235000.0
# Image saved as v_at_iteration_20.png
# Iteration 20 completed in 18s
# Start of iteration 21
# Current loss value: 1668326700.0
# Image saved as v_at_iteration_21.png
# Iteration 21 completed in 18s
# Start of iteration 22
# Current loss value: 1664019200.0
# Image saved as v_at_iteration_22.png
# Iteration 22 completed in 18s
# Start of iteration 23
# Current loss value: 1660414200.0
# Image saved as v_at_iteration_23.png
# Iteration 23 completed in 18s
# Start of iteration 24
# Current loss value: 1657465900.0
# Image saved as v_at_iteration_24.png
# Iteration 24 completed in 18s
# Start of iteration 25
# Current loss value: 1654489600.0
# Image saved as v_at_iteration_25.png
# Iteration 25 completed in 18s
# Start of iteration 26
# Current loss value: 1651491300.0
# Image saved as v_at_iteration_26.png
# Iteration 26 completed in 18s
# Start of iteration 27
# Current loss value: 1648821200.0
# Image saved as v_at_iteration_27.png
# Iteration 27 completed in 18s
# Start of iteration 28
# Current loss value: 1645965600.0
# Image saved as v_at_iteration_28.png
# Iteration 28 completed in 18s
# Start of iteration 29
# Current loss value: 1643262500.0
# Image saved as v_at_iteration_29.png
# Iteration 29 completed in 18s
# Start of iteration 30
# Current loss value: 1641075000.0
# Image saved as v_at_iteration_30.png
# Iteration 30 completed in 18s
# Start of iteration 31
# Current loss value: 1638841300.0
# Image saved as v_at_iteration_31.png
# Iteration 31 completed in 18s
# Start of iteration 32
# Current loss value: 1636690600.0
# Image saved as v_at_iteration_32.png
# Iteration 32 completed in 18s
# Start of iteration 33
# Current loss value: 1634752800.0
# Image saved as v_at_iteration_33.png
# Iteration 33 completed in 18s
# Start of iteration 34
# Current loss value: 1632730900.0
# Image saved as v_at_iteration_34.png
# Iteration 34 completed in 18s
# Start of iteration 35
# Current loss value: 1630854100.0
# Image saved as v_at_iteration_35.png
# Iteration 35 completed in 18s
# Start of iteration 36
# Current loss value: 1629297000.0
# Image saved as v_at_iteration_36.png
# Iteration 36 completed in 18s
# Start of iteration 37
# Current loss value: 1627762200.0
# Image saved as v_at_iteration_37.png
# Iteration 37 completed in 18s
# Start of iteration 38
# Current loss value: 1626186200.0
# Image saved as v_at_iteration_38.png
# Iteration 38 completed in 18s
# Start of iteration 39
# Current loss value: 1624803300.0
# Image saved as v_at_iteration_39.png
# Iteration 39 completed in 18s
# Start of iteration 40
# Current loss value: 1623356900.0
# Image saved as v_at_iteration_40.png
# Iteration 40 completed in 18s
# Start of iteration 41
# Current loss value: 1621787000.0
# Image saved as v_at_iteration_41.png
# Iteration 41 completed in 18s
# Start of iteration 42
# Current loss value: 1620422100.0
# Image saved as v_at_iteration_42.png
# Iteration 42 completed in 18s
# Start of iteration 43
# Current loss value: 1619000300.0
# Image saved as v_at_iteration_43.png
# Iteration 43 completed in 18s
# Start of iteration 44
# Current loss value: 1617696300.0
# Image saved as v_at_iteration_44.png
# Iteration 44 completed in 18s
# Start of iteration 45
# Current loss value: 1616469600.0
# Image saved as v_at_iteration_45.png
# Iteration 45 completed in 18s
# Start of iteration 46
# Current loss value: 1615223300.0
# Image saved as v_at_iteration_46.png
# Iteration 46 completed in 18s
# Start of iteration 47
# Current loss value: 1613955100.0
# Image saved as v_at_iteration_47.png
# Iteration 47 completed in 18s
# Start of iteration 48
# Current loss value: 1612826600.0
# Image saved as v_at_iteration_48.png
# Iteration 48 completed in 18s
# Start of iteration 49
# Current loss value: 1611744800.0
# Image saved as v_at_iteration_49.png
# Iteration 49 completed in 18s
# Start of iteration 50
# Current loss value: 1610675800.0
# Image saved as v_at_iteration_50.png
# Iteration 50 completed in 18s
# Start of iteration 51
# Current loss value: 1609750500.0
# Image saved as v_at_iteration_51.png
# Iteration 51 completed in 18s
# Start of iteration 52
# Current loss value: 1608803700.0
# Image saved as v_at_iteration_52.png
# Iteration 52 completed in 18s
# Start of iteration 53
# Current loss value: 1607931800.0
# Image saved as v_at_iteration_53.png
# Iteration 53 completed in 18s
# Start of iteration 54
# Current loss value: 1607068900.0
# Image saved as v_at_iteration_54.png
# Iteration 54 completed in 18s
# Start of iteration 55
# Current loss value: 1606135000.0
# Image saved as v_at_iteration_55.png
# Iteration 55 completed in 18s
# Start of iteration 56
# Current loss value: 1605260300.0
# Image saved as v_at_iteration_56.png
# Iteration 56 completed in 18s
# Start of iteration 57
# Current loss value: 1604402700.0
# Image saved as v_at_iteration_57.png
# Iteration 57 completed in 18s
# Start of iteration 58
# Current loss value: 1603530800.0
# Image saved as v_at_iteration_58.png
# Iteration 58 completed in 18s
# Start of iteration 59
# Current loss value: 1602751200.0
# Image saved as v_at_iteration_59.png
# Iteration 59 completed in 18s
# Start of iteration 60
# Current loss value: 1602003500.0
# Image saved as v_at_iteration_60.png
# Iteration 60 completed in 18s
# Start of iteration 61
# Current loss value: 1601272800.0
# Image saved as v_at_iteration_61.png
# Iteration 61 completed in 18s
# Start of iteration 62
# Current loss value: 1600561700.0
# Image saved as v_at_iteration_62.png
# Iteration 62 completed in 18s
# Start of iteration 63
# Current loss value: 1599863200.0
# Image saved as v_at_iteration_63.png
# Iteration 63 completed in 18s
# Start of iteration 64
# Current loss value: 1599198300.0
# Image saved as v_at_iteration_64.png
# Iteration 64 completed in 18s
# Start of iteration 65
# Current loss value: 1598513700.0
# Image saved as v_at_iteration_65.png
# Iteration 65 completed in 18s
# Start of iteration 66
# Current loss value: 1597884500.0
# Image saved as v_at_iteration_66.png
# Iteration 66 completed in 18s
# Start of iteration 67
# Current loss value: 1597277400.0
# Image saved as v_at_iteration_67.png
# Iteration 67 completed in 18s
# Start of iteration 68
# Current loss value: 1596678400.0
# Image saved as v_at_iteration_68.png
# Iteration 68 completed in 18s
# Start of iteration 69
# Current loss value: 1596096800.0
# Image saved as v_at_iteration_69.png
# Iteration 69 completed in 18s
# Start of iteration 70
# Current loss value: 1595491800.0
# Image saved as v_at_iteration_70.png
# Iteration 70 completed in 18s
# Start of iteration 71
# Current loss value: 1594890100.0
# Image saved as v_at_iteration_71.png
# Iteration 71 completed in 18s
# Start of iteration 72
# Current loss value: 1594284500.0
# Image saved as v_at_iteration_72.png
# Iteration 72 completed in 18s
# Start of iteration 73
# Current loss value: 1593726600.0
# Image saved as v_at_iteration_73.png
# Iteration 73 completed in 18s
# Start of iteration 74
# Current loss value: 1593149300.0
# Image saved as v_at_iteration_74.png
# Iteration 74 completed in 18s
# Start of iteration 75
# Current loss value: 1592635400.0
# Image saved as v_at_iteration_75.png
# Iteration 75 completed in 18s
# Start of iteration 76
# Current loss value: 1592140000.0
# Image saved as v_at_iteration_76.png
# Iteration 76 completed in 18s
# Start of iteration 77
# Current loss value: 1591648300.0
# Image saved as v_at_iteration_77.png
# Iteration 77 completed in 18s
# Start of iteration 78
# Current loss value: 1591128800.0
# Image saved as v_at_iteration_78.png
# Iteration 78 completed in 18s
# Start of iteration 79
# Current loss value: 1590653800.0
# Image saved as v_at_iteration_79.png
# Iteration 79 completed in 18s
# Start of iteration 80
# Current loss value: 1590199400.0
# Image saved as v_at_iteration_80.png
# Iteration 80 completed in 18s
# Start of iteration 81
# Current loss value: 1589761300.0
# Image saved as v_at_iteration_81.png
# Iteration 81 completed in 18s
# Start of iteration 82
# Current loss value: 1589347800.0
# Image saved as v_at_iteration_82.png
# Iteration 82 completed in 18s
# Start of iteration 83
# Current loss value: 1588895200.0
# Image saved as v_at_iteration_83.png
# Iteration 83 completed in 18s
# Start of iteration 84
# Current loss value: 1588460300.0
# Image saved as v_at_iteration_84.png
# Iteration 84 completed in 18s
# Start of iteration 85
# Current loss value: 1588061200.0
# Image saved as v_at_iteration_85.png
# Iteration 85 completed in 18s
# Start of iteration 86
# Current loss value: 1587639000.0
# Image saved as v_at_iteration_86.png
# Iteration 86 completed in 18s
# Start of iteration 87
# Current loss value: 1587188700.0
# Image saved as v_at_iteration_87.png
# Iteration 87 completed in 18s
# Start of iteration 88
# Current loss value: 1586743300.0
# Image saved as v_at_iteration_88.png
# Iteration 88 completed in 18s
# Start of iteration 89
# Current loss value: 1586339000.0
# Image saved as v_at_iteration_89.png
# Iteration 89 completed in 18s
# Start of iteration 90
# Current loss value: 1585939700.0
# Image saved as v_at_iteration_90.png
# Iteration 90 completed in 18s
# Start of iteration 91
# Current loss value: 1585513200.0
# Image saved as v_at_iteration_91.png
# Iteration 91 completed in 18s
# Start of iteration 92
# Current loss value: 1585100800.0
# Image saved as v_at_iteration_92.png
# Iteration 92 completed in 18s
# Start of iteration 93
# Current loss value: 1584698400.0
# Image saved as v_at_iteration_93.png
# Iteration 93 completed in 18s
# Start of iteration 94
# Current loss value: 1584284200.0
# Image saved as v_at_iteration_94.png
# Iteration 94 completed in 18s
# Start of iteration 95
# Current loss value: 1583865300.0
# Image saved as v_at_iteration_95.png
# Iteration 95 completed in 18s
# Start of iteration 96
# Current loss value: 1583425300.0
# Image saved as v_at_iteration_96.png
# Iteration 96 completed in 18s
# Start of iteration 97
# Current loss value: 1582980400.0
# Image saved as v_at_iteration_97.png
# Iteration 97 completed in 18s
# Start of iteration 98
# Current loss value: 1582549900.0
# Image saved as v_at_iteration_98.png
# Iteration 98 completed in 18s
# Start of iteration 99
# Current loss value: 1582080800.0
# Image saved as v_at_iteration_99.png
# Iteration 99 completed in 18s
# Start of iteration 100
# Current loss value: 1581615000.0
# Image saved as v_at_iteration_100.png
# Iteration 100 completed in 18s
# Start of iteration 101
# Current loss value: 1581169400.0
# Image saved as v_at_iteration_101.png
# Iteration 101 completed in 18s
# Start of iteration 102
# Current loss value: 1580718300.0
# Image saved as v_at_iteration_102.png
# Iteration 102 completed in 18s
# Start of iteration 103
# Current loss value: 1580214000.0
# Image saved as v_at_iteration_103.png
# Iteration 103 completed in 18s
# Start of iteration 104
# Current loss value: 1579699200.0
# Image saved as v_at_iteration_104.png
# Iteration 104 completed in 18s
# Start of iteration 105
# Current loss value: 1579214800.0
# Image saved as v_at_iteration_105.png
# Iteration 105 completed in 18s
# Start of iteration 106
# Current loss value: 1578720100.0
# Image saved as v_at_iteration_106.png
# Iteration 106 completed in 18s
# Start of iteration 107
# Current loss value: 1578234600.0
# Image saved as v_at_iteration_107.png
# Iteration 107 completed in 18s
# Start of iteration 108
# Current loss value: 1577763600.0
# Image saved as v_at_iteration_108.png
# Iteration 108 completed in 18s
# Start of iteration 109
# Current loss value: 1577258500.0
# Image saved as v_at_iteration_109.png
# Iteration 109 completed in 18s
# Start of iteration 110
# Current loss value: 1576754700.0
# Image saved as v_at_iteration_110.png
# Iteration 110 completed in 18s
# Start of iteration 111
# Current loss value: 1576213200.0
# Image saved as v_at_iteration_111.png
# Iteration 111 completed in 18s
# Start of iteration 112
# Current loss value: 1575654100.0
# Image saved as v_at_iteration_112.png
# Iteration 112 completed in 18s
# Start of iteration 113
# Current loss value: 1575128700.0
# Image saved as v_at_iteration_113.png
# Iteration 113 completed in 18s
# Start of iteration 114
# Current loss value: 1574582000.0
# Image saved as v_at_iteration_114.png
# Iteration 114 completed in 18s
# Start of iteration 115
# Current loss value: 1573998600.0
# Image saved as v_at_iteration_115.png
# Iteration 115 completed in 18s
# Start of iteration 116
# Current loss value: 1573381600.0
# Image saved as v_at_iteration_116.png
# Iteration 116 completed in 18s
# Start of iteration 117
# Current loss value: 1572804100.0
# Image saved as v_at_iteration_117.png
# Iteration 117 completed in 18s
# Start of iteration 118
# Current loss value: 1572172800.0
# Image saved as v_at_iteration_118.png
# Iteration 118 completed in 18s
# Start of iteration 119
# Current loss value: 1571444500.0
# Image saved as v_at_iteration_119.png
# Iteration 119 completed in 18s
# Start of iteration 120
# Current loss value: 1570729500.0
# Image saved as v_at_iteration_120.png
# Iteration 120 completed in 18s
# Start of iteration 121
# Current loss value: 1569931500.0
# Image saved as v_at_iteration_121.png
# Iteration 121 completed in 18s
# Start of iteration 122
# Current loss value: 1569040100.0
# Image saved as v_at_iteration_122.png
# Iteration 122 completed in 18s
# Start of iteration 123
# Current loss value: 1568169300.0
# Image saved as v_at_iteration_123.png
# Iteration 123 completed in 18s
# Start of iteration 124
# Current loss value: 1567341300.0
# Image saved as v_at_iteration_124.png
# Iteration 124 completed in 18s
# Start of iteration 125
# Current loss value: 1566410200.0
# Image saved as v_at_iteration_125.png
# Iteration 125 completed in 18s
# Start of iteration 126
# Current loss value: 1565459000.0
# Image saved as v_at_iteration_126.png
# Iteration 126 completed in 18s
# Start of iteration 127
# Current loss value: 1564402400.0
# Image saved as v_at_iteration_127.png
# Iteration 127 completed in 18s
# Start of iteration 128
# Current loss value: 1563289000.0
# Image saved as v_at_iteration_128.png
# Iteration 128 completed in 18s
# Start of iteration 129
# Current loss value: 1562115100.0
# Image saved as v_at_iteration_129.png
# Iteration 129 completed in 18s
# Start of iteration 130
# Current loss value: 1560649000.0
# Image saved as v_at_iteration_130.png
# Iteration 130 completed in 18s
# Start of iteration 131
# Current loss value: 1559347300.0
# Image saved as v_at_iteration_131.png
# Iteration 131 completed in 18s
# Start of iteration 132
# Current loss value: 1558071200.0
# Image saved as v_at_iteration_132.png
# Iteration 132 completed in 18s
# Start of iteration 133
# Current loss value: 1556536200.0
# Image saved as v_at_iteration_133.png
# Iteration 133 completed in 18s
# Start of iteration 134
# Current loss value: 1554637800.0
# Image saved as v_at_iteration_134.png
# Iteration 134 completed in 18s
# Start of iteration 135
# Current loss value: 1553313500.0
# Image saved as v_at_iteration_135.png
# Iteration 135 completed in 18s
# Start of iteration 136
# Current loss value: 1551711000.0
# Image saved as v_at_iteration_136.png
# Iteration 136 completed in 18s
# Start of iteration 137
# Current loss value: 1550069200.0
# Image saved as v_at_iteration_137.png
# Iteration 137 completed in 18s
# Start of iteration 138
# Current loss value: 1548315100.0
# Image saved as v_at_iteration_138.png
# Iteration 138 completed in 18s
# Start of iteration 139
# Current loss value: 1546681600.0
# Image saved as v_at_iteration_139.png
# Iteration 139 completed in 18s
# Start of iteration 140
# Current loss value: 1544745300.0
# Image saved as v_at_iteration_140.png
# Iteration 140 completed in 18s
# Start of iteration 141
# Current loss value: 1542960800.0
# Image saved as v_at_iteration_141.png
# Iteration 141 completed in 18s
# Start of iteration 142
# Current loss value: 1541266400.0
# Image saved as v_at_iteration_142.png
# Iteration 142 completed in 18s
# Start of iteration 143
# Current loss value: 1539335400.0
# Image saved as v_at_iteration_143.png
# Iteration 143 completed in 18s
# Start of iteration 144
# Current loss value: 1537311700.0
# Image saved as v_at_iteration_144.png
# Iteration 144 completed in 18s
# Start of iteration 145
# Current loss value: 1535506200.0
# Image saved as v_at_iteration_145.png
# Iteration 145 completed in 18s
# Start of iteration 146
# Current loss value: 1533654300.0
# Image saved as v_at_iteration_146.png
# Iteration 146 completed in 18s
# Start of iteration 147
# Current loss value: 1531675900.0
# Image saved as v_at_iteration_147.png
# Iteration 147 completed in 18s
# Start of iteration 148
# Current loss value: 1529702100.0
# Image saved as v_at_iteration_148.png
# Iteration 148 completed in 18s
# Start of iteration 149
# Current loss value: 1527698700.0
# Image saved as v_at_iteration_149.png
# Iteration 149 completed in 18s
# Start of iteration 150
# Current loss value: 1525727200.0
# Image saved as v_at_iteration_150.png
# Iteration 150 completed in 18s
# Start of iteration 151
# Current loss value: 1523765200.0
# Image saved as v_at_iteration_151.png
# Iteration 151 completed in 18s
# Start of iteration 152
# Current loss value: 1521410300.0
# Image saved as v_at_iteration_152.png
# Iteration 152 completed in 18s
# Start of iteration 153
# Current loss value: 1518984700.0
# Image saved as v_at_iteration_153.png
# Iteration 153 completed in 18s
# Start of iteration 154
# Current loss value: 1516569100.0
# Image saved as v_at_iteration_154.png
# Iteration 154 completed in 18s
# Start of iteration 155
# Current loss value: 1514057500.0
# Image saved as v_at_iteration_155.png
# Iteration 155 completed in 18s
# Start of iteration 156
# Current loss value: 1511319800.0
# Image saved as v_at_iteration_156.png
# Iteration 156 completed in 18s
# Start of iteration 157
# Current loss value: 1508501200.0
# Image saved as v_at_iteration_157.png
# Iteration 157 completed in 18s
# Start of iteration 158
# Current loss value: 1506179500.0
# Image saved as v_at_iteration_158.png
# Iteration 158 completed in 18s
# Start of iteration 159
# Current loss value: 1503742200.0
# Image saved as v_at_iteration_159.png
# Iteration 159 completed in 18s
# Start of iteration 160
# Current loss value: 1501666800.0
# Image saved as v_at_iteration_160.png
# Iteration 160 completed in 18s
# Start of iteration 161
# Current loss value: 1499540700.0
# Image saved as v_at_iteration_161.png
# Iteration 161 completed in 18s
# Start of iteration 162
# Current loss value: 1497334000.0
# Image saved as v_at_iteration_162.png
# Iteration 162 completed in 18s
# Start of iteration 163
# Current loss value: 1495101400.0
# Image saved as v_at_iteration_163.png
# Iteration 163 completed in 18s
# Start of iteration 164
# Current loss value: 1493102300.0
# Image saved as v_at_iteration_164.png
# Iteration 164 completed in 19s
# Start of iteration 165
# Current loss value: 1490894300.0
# Image saved as v_at_iteration_165.png
# Iteration 165 completed in 18s
# Start of iteration 166
# Current loss value: 1488692000.0
# Image saved as v_at_iteration_166.png
# Iteration 166 completed in 18s
# Start of iteration 167
# Current loss value: 1486540000.0
# Image saved as v_at_iteration_167.png
# Iteration 167 completed in 18s
# Start of iteration 168
# Current loss value: 1484794400.0
# Image saved as v_at_iteration_168.png
# Iteration 168 completed in 18s
# Start of iteration 169
# Current loss value: 1483157800.0
# Image saved as v_at_iteration_169.png
# Iteration 169 completed in 18s
# Start of iteration 170
# Current loss value: 1481461000.0
# Image saved as v_at_iteration_170.png
# Iteration 170 completed in 18s
# Start of iteration 171
# Current loss value: 1479604200.0
# Image saved as v_at_iteration_171.png
# Iteration 171 completed in 18s
# Start of iteration 172
# Current loss value: 1478032500.0
# Image saved as v_at_iteration_172.png
# Iteration 172 completed in 18s
# Start of iteration 173
# Current loss value: 1476455700.0
# Image saved as v_at_iteration_173.png
# Iteration 173 completed in 18s
# Start of iteration 174
# Current loss value: 1474713300.0
# Image saved as v_at_iteration_174.png
# Iteration 174 completed in 18s
# Start of iteration 175
# Current loss value: 1473158100.0
# Image saved as v_at_iteration_175.png
# Iteration 175 completed in 18s
# Start of iteration 176
# Current loss value: 1471323000.0
# Image saved as v_at_iteration_176.png
# Iteration 176 completed in 18s
# Start of iteration 177
# Current loss value: 1470028200.0
# Image saved as v_at_iteration_177.png
# Iteration 177 completed in 18s
# Start of iteration 178
# Current loss value: 1468725900.0
# Image saved as v_at_iteration_178.png
# Iteration 178 completed in 18s
# Start of iteration 179
# Current loss value: 1467525500.0
# Image saved as v_at_iteration_179.png
# Iteration 179 completed in 18s
# Start of iteration 180
# Current loss value: 1466306800.0
# Image saved as v_at_iteration_180.png
# Iteration 180 completed in 18s
# Start of iteration 181
# Current loss value: 1465350100.0
# Image saved as v_at_iteration_181.png
# Iteration 181 completed in 18s
# Start of iteration 182
# Current loss value: 1464411900.0
# Image saved as v_at_iteration_182.png
# Iteration 182 completed in 18s
# Start of iteration 183
# Current loss value: 1463504400.0
# Image saved as v_at_iteration_183.png
# Iteration 183 completed in 18s
# Start of iteration 184
# Current loss value: 1462556700.0
# Image saved as v_at_iteration_184.png
# Iteration 184 completed in 18s
# Start of iteration 185
# Current loss value: 1461751300.0
# Image saved as v_at_iteration_185.png
# Iteration 185 completed in 18s
# Start of iteration 186
# Current loss value: 1460932400.0
# Image saved as v_at_iteration_186.png
# Iteration 186 completed in 18s
# Start of iteration 187
# Current loss value: 1460234600.0
# Image saved as v_at_iteration_187.png
# Iteration 187 completed in 18s
# Start of iteration 188
# Current loss value: 1459542700.0
# Image saved as v_at_iteration_188.png
# Iteration 188 completed in 18s
# Start of iteration 189
# Current loss value: 1458910700.0
# Image saved as v_at_iteration_189.png
# Iteration 189 completed in 18s
# Start of iteration 190
# Current loss value: 1458331400.0
# Image saved as v_at_iteration_190.png
# Iteration 190 completed in 18s
# Start of iteration 191
# Current loss value: 1457795600.0
# Image saved as v_at_iteration_191.png
# Iteration 191 completed in 18s
# Start of iteration 192
# Current loss value: 1457287600.0
# Image saved as v_at_iteration_192.png
# Iteration 192 completed in 18s
# Start of iteration 193
# Current loss value: 1456816900.0
# Image saved as v_at_iteration_193.png
# Iteration 193 completed in 18s
# Start of iteration 194
# Current loss value: 1456357400.0
# Image saved as v_at_iteration_194.png
# Iteration 194 completed in 18s
# Start of iteration 195
# Current loss value: 1455944700.0
# Image saved as v_at_iteration_195.png
# Iteration 195 completed in 18s
# Start of iteration 196
# Current loss value: 1455520800.0
# Image saved as v_at_iteration_196.png
# Iteration 196 completed in 18s
# Start of iteration 197
# Current loss value: 1455157400.0
# Image saved as v_at_iteration_197.png
# Iteration 197 completed in 18s
# Start of iteration 198
# Current loss value: 1454843100.0
# Image saved as v_at_iteration_198.png
# Iteration 198 completed in 18s
# Start of iteration 199
# Current loss value: 1454559000.0
# Image saved as v_at_iteration_199.png
# Iteration 199 completed in 18s
# Model loaded.
# Start of iteration 0
# Current loss value: 10947182000.0
# Image saved as w_at_iteration_0.png
# Iteration 0 completed in 18s
# Start of iteration 1
# Current loss value: 6374762500.0
# Image saved as w_at_iteration_1.png
# Iteration 1 completed in 18s
# Start of iteration 2
# Current loss value: 5162268700.0
# Image saved as w_at_iteration_2.png
# Iteration 2 completed in 18s
# Start of iteration 3
# Current loss value: 4683714600.0
# Image saved as w_at_iteration_3.png
# Iteration 3 completed in 18s
# Start of iteration 4
# Current loss value: 4380996000.0
# Image saved as w_at_iteration_4.png
# Iteration 4 completed in 18s
# Start of iteration 5
# Current loss value: 4167849200.0
# Image saved as w_at_iteration_5.png
# Iteration 5 completed in 18s
# Start of iteration 6
# Current loss value: 4025833000.0
# Image saved as w_at_iteration_6.png
# Iteration 6 completed in 18s
# Start of iteration 7
# Current loss value: 3916632600.0
# Image saved as w_at_iteration_7.png
# Iteration 7 completed in 18s
# Start of iteration 8
# Current loss value: 3836367600.0
# Image saved as w_at_iteration_8.png
# Iteration 8 completed in 18s
# Start of iteration 9
# Current loss value: 3767060000.0
# Image saved as w_at_iteration_9.png
# Iteration 9 completed in 18s
# Start of iteration 10
# Current loss value: 3701710800.0
# Image saved as w_at_iteration_10.png
# Iteration 10 completed in 18s
# Start of iteration 11
# Current loss value: 3641852400.0
# Image saved as w_at_iteration_11.png
# Iteration 11 completed in 18s
# Start of iteration 12
# Current loss value: 3597749200.0
# Image saved as w_at_iteration_12.png
# Iteration 12 completed in 18s
# Start of iteration 13
# Current loss value: 3549149700.0
# Image saved as w_at_iteration_13.png
# Iteration 13 completed in 18s
# Start of iteration 14
# Current loss value: 3511437000.0
# Image saved as w_at_iteration_14.png
# Iteration 14 completed in 18s
# Start of iteration 15
# Current loss value: 3477462300.0
# Image saved as w_at_iteration_15.png
# Iteration 15 completed in 18s
# Start of iteration 16
# Current loss value: 3449159200.0
# Image saved as w_at_iteration_16.png
# Iteration 16 completed in 18s
# Start of iteration 17
# Current loss value: 3412212700.0
# Image saved as w_at_iteration_17.png
# Iteration 17 completed in 18s
# Start of iteration 18
# Current loss value: 3380949500.0
# Image saved as w_at_iteration_18.png
# Iteration 18 completed in 18s
# Start of iteration 19
# Current loss value: 3356851200.0
# Image saved as w_at_iteration_19.png
# Iteration 19 completed in 18s
# Start of iteration 20
# Current loss value: 3335240000.0
# Image saved as w_at_iteration_20.png
# Iteration 20 completed in 18s
# Start of iteration 21
# Current loss value: 3312662000.0
# Image saved as w_at_iteration_21.png
# Iteration 21 completed in 18s
# Start of iteration 22
# Current loss value: 3290374000.0
# Image saved as w_at_iteration_22.png
# Iteration 22 completed in 18s
# Start of iteration 23
# Current loss value: 3268173600.0
# Image saved as w_at_iteration_23.png
# Iteration 23 completed in 18s
# Start of iteration 24
# Current loss value: 3243616000.0
# Image saved as w_at_iteration_24.png
# Iteration 24 completed in 18s
# Start of iteration 25
# Current loss value: 3224307200.0
# Image saved as w_at_iteration_25.png
# Iteration 25 completed in 18s
# Start of iteration 26
# Current loss value: 3210981400.0
# Image saved as w_at_iteration_26.png
# Iteration 26 completed in 18s
# Start of iteration 27
# Current loss value: 3196390400.0
# Image saved as w_at_iteration_27.png
# Iteration 27 completed in 19s
# Start of iteration 28
# Current loss value: 3184465400.0
# Image saved as w_at_iteration_28.png
# Iteration 28 completed in 18s
# Start of iteration 29
# Current loss value: 3171096000.0
# Image saved as w_at_iteration_29.png
# Iteration 29 completed in 18s
# Start of iteration 30
# Current loss value: 3160169500.0
# Image saved as w_at_iteration_30.png
# Iteration 30 completed in 18s
# Start of iteration 31
# Current loss value: 3147457800.0
# Image saved as w_at_iteration_31.png
# Iteration 31 completed in 18s
# Start of iteration 32
# Current loss value: 3134880300.0
# Image saved as w_at_iteration_32.png
# Iteration 32 completed in 18s
# Start of iteration 33
# Current loss value: 3121038600.0
# Image saved as w_at_iteration_33.png
# Iteration 33 completed in 18s
# Start of iteration 34
# Current loss value: 3108936200.0
# Image saved as w_at_iteration_34.png
# Iteration 34 completed in 18s
# Start of iteration 35
# Current loss value: 3099875800.0
# Image saved as w_at_iteration_35.png
# Iteration 35 completed in 18s
# Start of iteration 36
# Current loss value: 3088408000.0
# Image saved as w_at_iteration_36.png
# Iteration 36 completed in 19s
# Start of iteration 37
# Current loss value: 3078993000.0
# Image saved as w_at_iteration_37.png
# Iteration 37 completed in 18s
# Start of iteration 38
# Current loss value: 3071532000.0
# Image saved as w_at_iteration_38.png
# Iteration 38 completed in 18s
# Start of iteration 39
# Current loss value: 3062206000.0
# Image saved as w_at_iteration_39.png
# Iteration 39 completed in 18s
# Start of iteration 40
# Current loss value: 3053176300.0
# Image saved as w_at_iteration_40.png
# Iteration 40 completed in 18s
# Start of iteration 41
# Current loss value: 3044349400.0
# Image saved as w_at_iteration_41.png
# Iteration 41 completed in 18s
# Start of iteration 42
# Current loss value: 3035660300.0
# Image saved as w_at_iteration_42.png
# Iteration 42 completed in 18s
# Start of iteration 43
# Current loss value: 3026694000.0
# Image saved as w_at_iteration_43.png
# Iteration 43 completed in 18s
# Start of iteration 44
# Current loss value: 3017994200.0
# Image saved as w_at_iteration_44.png
# Iteration 44 completed in 18s
# Start of iteration 45
# Current loss value: 3009132500.0
# Image saved as w_at_iteration_45.png
# Iteration 45 completed in 18s
# Start of iteration 46
# Current loss value: 3001663500.0
# Image saved as w_at_iteration_46.png
# Iteration 46 completed in 18s
# Start of iteration 47
# Current loss value: 2994632700.0
# Image saved as w_at_iteration_47.png
# Iteration 47 completed in 19s
# Start of iteration 48
# Current loss value: 2987960300.0
# Image saved as w_at_iteration_48.png
# Iteration 48 completed in 19s
# Start of iteration 49
# Current loss value: 2981557800.0
# Image saved as w_at_iteration_49.png
# Iteration 49 completed in 18s
# Start of iteration 50
# Current loss value: 2975755300.0
# Image saved as w_at_iteration_50.png
# Iteration 50 completed in 18s
# Start of iteration 51
# Current loss value: 2970779400.0
# Image saved as w_at_iteration_51.png
# Iteration 51 completed in 18s
# Start of iteration 52
# Current loss value: 2965319700.0
# Image saved as w_at_iteration_52.png
# Iteration 52 completed in 18s
# Start of iteration 53
# Current loss value: 2958005000.0
# Image saved as w_at_iteration_53.png
# Iteration 53 completed in 18s
# Start of iteration 54
# Current loss value: 2951869400.0
# Image saved as w_at_iteration_54.png
# Iteration 54 completed in 18s
# Start of iteration 55
# Current loss value: 2944955000.0
# Image saved as w_at_iteration_55.png
# Iteration 55 completed in 18s
# Start of iteration 56
# Current loss value: 2938095600.0
# Image saved as w_at_iteration_56.png
# Iteration 56 completed in 18s
# Start of iteration 57
# Current loss value: 2933351000.0
# Image saved as w_at_iteration_57.png
# Iteration 57 completed in 18s
# Start of iteration 58
# Current loss value: 2929112800.0
# Image saved as w_at_iteration_58.png
# Iteration 58 completed in 18s
# Start of iteration 59
# Current loss value: 2924920800.0
# Image saved as w_at_iteration_59.png
# Iteration 59 completed in 18s
# Start of iteration 60
# Current loss value: 2920382200.0
# Image saved as w_at_iteration_60.png
# Iteration 60 completed in 18s
# Start of iteration 61
# Current loss value: 2915795500.0
# Image saved as w_at_iteration_61.png
# Iteration 61 completed in 18s
# Start of iteration 62
# Current loss value: 2912128000.0
# Image saved as w_at_iteration_62.png
# Iteration 62 completed in 18s
# Start of iteration 63
# Current loss value: 2907774500.0
# Image saved as w_at_iteration_63.png
# Iteration 63 completed in 18s
# Start of iteration 64
# Current loss value: 2903914200.0
# Image saved as w_at_iteration_64.png
# Iteration 64 completed in 18s
# Start of iteration 65
# Current loss value: 2898628000.0
# Image saved as w_at_iteration_65.png
# Iteration 65 completed in 18s
# Start of iteration 66
# Current loss value: 2894358000.0
# Image saved as w_at_iteration_66.png
# Iteration 66 completed in 18s
# Start of iteration 67
# Current loss value: 2890755800.0
# Image saved as w_at_iteration_67.png
# Iteration 67 completed in 18s
# Start of iteration 68
# Current loss value: 2886709500.0
# Image saved as w_at_iteration_68.png
# Iteration 68 completed in 18s
# Start of iteration 69
# Current loss value: 2883009800.0
# Image saved as w_at_iteration_69.png
# Iteration 69 completed in 18s
# Start of iteration 70
# Current loss value: 2879694300.0
# Image saved as w_at_iteration_70.png
# Iteration 70 completed in 18s
# Start of iteration 71
# Current loss value: 2876169200.0
# Image saved as w_at_iteration_71.png
# Iteration 71 completed in 18s
# Start of iteration 72
# Current loss value: 2872564500.0
# Image saved as w_at_iteration_72.png
# Iteration 72 completed in 18s
# Start of iteration 73
# Current loss value: 2868574500.0
# Image saved as w_at_iteration_73.png
# Iteration 73 completed in 18s
# Start of iteration 74
# Current loss value: 2865429200.0
# Image saved as w_at_iteration_74.png
# Iteration 74 completed in 18s
# Start of iteration 75
# Current loss value: 2861562000.0
# Image saved as w_at_iteration_75.png
# Iteration 75 completed in 18s
# Start of iteration 76
# Current loss value: 2858504400.0
# Image saved as w_at_iteration_76.png
# Iteration 76 completed in 18s
# Start of iteration 77
# Current loss value: 2855272200.0
# Image saved as w_at_iteration_77.png
# Iteration 77 completed in 18s
# Start of iteration 78
# Current loss value: 2852591600.0
# Image saved as w_at_iteration_78.png
# Iteration 78 completed in 18s
# Start of iteration 79
# Current loss value: 2849132000.0
# Image saved as w_at_iteration_79.png
# Iteration 79 completed in 18s
# Start of iteration 80
# Current loss value: 2846195200.0
# Image saved as w_at_iteration_80.png
# Iteration 80 completed in 18s
# Start of iteration 81
# Current loss value: 2843464400.0
# Image saved as w_at_iteration_81.png
# Iteration 81 completed in 18s
# Start of iteration 82
# Current loss value: 2840718800.0
# Image saved as w_at_iteration_82.png
# Iteration 82 completed in 18s
# Start of iteration 83
# Current loss value: 2838183000.0
# Image saved as w_at_iteration_83.png
# Iteration 83 completed in 18s
# Start of iteration 84
# Current loss value: 2835602000.0
# Image saved as w_at_iteration_84.png
# Iteration 84 completed in 18s
# Start of iteration 85
# Current loss value: 2832980200.0
# Image saved as w_at_iteration_85.png
# Iteration 85 completed in 18s
# Start of iteration 86
# Current loss value: 2830139000.0
# Image saved as w_at_iteration_86.png
# Iteration 86 completed in 19s
# Start of iteration 87
# Current loss value: 2827294200.0
# Image saved as w_at_iteration_87.png
# Iteration 87 completed in 18s
# Start of iteration 88
# Current loss value: 2824751900.0
# Image saved as w_at_iteration_88.png
# Iteration 88 completed in 18s
# Start of iteration 89
# Current loss value: 2822551300.0
# Image saved as w_at_iteration_89.png
# Iteration 89 completed in 18s
# Start of iteration 90
# Current loss value: 2819556900.0
# Image saved as w_at_iteration_90.png
# Iteration 90 completed in 18s
# Start of iteration 91
# Current loss value: 2817160400.0
# Image saved as w_at_iteration_91.png
# Iteration 91 completed in 18s
# Start of iteration 92
# Current loss value: 2815061800.0
# Image saved as w_at_iteration_92.png
# Iteration 92 completed in 18s
# Start of iteration 93
# Current loss value: 2812710700.0
# Image saved as w_at_iteration_93.png
# Iteration 93 completed in 18s
# Start of iteration 94
# Current loss value: 2809996300.0
# Image saved as w_at_iteration_94.png
# Iteration 94 completed in 18s
# Start of iteration 95
# Current loss value: 2807472000.0
# Image saved as w_at_iteration_95.png
# Iteration 95 completed in 18s
# Start of iteration 96
# Current loss value: 2805412400.0
# Image saved as w_at_iteration_96.png
# Iteration 96 completed in 18s
# Start of iteration 97
# Current loss value: 2802550300.0
# Image saved as w_at_iteration_97.png
# Iteration 97 completed in 18s
# Start of iteration 98
# Current loss value: 2800274700.0
# Image saved as w_at_iteration_98.png
# Iteration 98 completed in 18s
# Start of iteration 99
# Current loss value: 2797917200.0
# Image saved as w_at_iteration_99.png
# Iteration 99 completed in 18s
# Start of iteration 100
# Current loss value: 2795878100.0
# Image saved as w_at_iteration_100.png
# Iteration 100 completed in 18s
# Start of iteration 101
# Current loss value: 2793651700.0
# Image saved as w_at_iteration_101.png
# Iteration 101 completed in 18s
# Start of iteration 102
# Current loss value: 2791694800.0
# Image saved as w_at_iteration_102.png
# Iteration 102 completed in 18s
# Start of iteration 103
# Current loss value: 2789498400.0
# Image saved as w_at_iteration_103.png
# Iteration 103 completed in 18s
# Start of iteration 104
# Current loss value: 2786924800.0
# Image saved as w_at_iteration_104.png
# Iteration 104 completed in 18s
# Start of iteration 105
# Current loss value: 2784648000.0
# Image saved as w_at_iteration_105.png
# Iteration 105 completed in 18s
# Start of iteration 106
# Current loss value: 2782325200.0
# Image saved as w_at_iteration_106.png
# Iteration 106 completed in 18s
# Start of iteration 107
# Current loss value: 2780427000.0
# Image saved as w_at_iteration_107.png
# Iteration 107 completed in 18s
# Start of iteration 108
# Current loss value: 2777606700.0
# Image saved as w_at_iteration_108.png
# Iteration 108 completed in 18s
# Start of iteration 109
# Current loss value: 2775385300.0
# Image saved as w_at_iteration_109.png
# Iteration 109 completed in 18s
# Start of iteration 110
# Current loss value: 2773635800.0
# Image saved as w_at_iteration_110.png
# Iteration 110 completed in 18s
# Start of iteration 111
# Current loss value: 2771815000.0
# Image saved as w_at_iteration_111.png
# Iteration 111 completed in 18s
# Start of iteration 112
# Current loss value: 2769661200.0
# Image saved as w_at_iteration_112.png
# Iteration 112 completed in 18s
# Start of iteration 113
# Current loss value: 2767836700.0
# Image saved as w_at_iteration_113.png
# Iteration 113 completed in 18s
# Start of iteration 114
# Current loss value: 2765848300.0
# Image saved as w_at_iteration_114.png
# Iteration 114 completed in 18s
# Start of iteration 115
# Current loss value: 2764134400.0
# Image saved as w_at_iteration_115.png
# Iteration 115 completed in 18s
# Start of iteration 116
# Current loss value: 2762414600.0
# Image saved as w_at_iteration_116.png
# Iteration 116 completed in 18s
# Start of iteration 117
# Current loss value: 2760860700.0
# Image saved as w_at_iteration_117.png
# Iteration 117 completed in 18s
# Start of iteration 118
# Current loss value: 2759226400.0
# Image saved as w_at_iteration_118.png
# Iteration 118 completed in 18s
# Start of iteration 119
# Current loss value: 2757471200.0
# Image saved as w_at_iteration_119.png
# Iteration 119 completed in 18s
# Start of iteration 120
# Current loss value: 2755981800.0
# Image saved as w_at_iteration_120.png
# Iteration 120 completed in 18s
# Start of iteration 121
# Current loss value: 2754322700.0
# Image saved as w_at_iteration_121.png
# Iteration 121 completed in 18s
# Start of iteration 122
# Current loss value: 2752686600.0
# Image saved as w_at_iteration_122.png
# Iteration 122 completed in 18s
# Start of iteration 123
# Current loss value: 2751021600.0
# Image saved as w_at_iteration_123.png
# Iteration 123 completed in 18s
# Start of iteration 124
# Current loss value: 2749169700.0
# Image saved as w_at_iteration_124.png
# Iteration 124 completed in 18s
# Start of iteration 125
# Current loss value: 2747160000.0
# Image saved as w_at_iteration_125.png
# Iteration 125 completed in 18s
# Start of iteration 126
# Current loss value: 2745366000.0
# Image saved as w_at_iteration_126.png
# Iteration 126 completed in 18s
# Start of iteration 127
# Current loss value: 2743556400.0
# Image saved as w_at_iteration_127.png
# Iteration 127 completed in 18s
# Start of iteration 128
# Current loss value: 2742185500.0
# Image saved as w_at_iteration_128.png
# Iteration 128 completed in 18s
# Start of iteration 129
# Current loss value: 2740555000.0
# Image saved as w_at_iteration_129.png
# Iteration 129 completed in 18s
# Start of iteration 130
# Current loss value: 2739063800.0
# Image saved as w_at_iteration_130.png
# Iteration 130 completed in 18s
# Start of iteration 131
# Current loss value: 2737717500.0
# Image saved as w_at_iteration_131.png
# Iteration 131 completed in 18s
# Start of iteration 132
# Current loss value: 2736497700.0
# Image saved as w_at_iteration_132.png
# Iteration 132 completed in 18s
# Start of iteration 133
# Current loss value: 2735175200.0
# Image saved as w_at_iteration_133.png
# Iteration 133 completed in 18s
# Start of iteration 134
# Current loss value: 2733884400.0
# Image saved as w_at_iteration_134.png
# Iteration 134 completed in 18s
# Start of iteration 135
# Current loss value: 2732669000.0
# Image saved as w_at_iteration_135.png
# Iteration 135 completed in 18s
# Start of iteration 136
# Current loss value: 2731338000.0
# Image saved as w_at_iteration_136.png
# Iteration 136 completed in 18s
# Start of iteration 137
# Current loss value: 2729799700.0
# Image saved as w_at_iteration_137.png
# Iteration 137 completed in 18s
# Start of iteration 138
# Current loss value: 2728373200.0
# Image saved as w_at_iteration_138.png
# Iteration 138 completed in 18s
# Start of iteration 139
# Current loss value: 2727146200.0
# Image saved as w_at_iteration_139.png
# Iteration 139 completed in 18s
# Start of iteration 140
# Current loss value: 2725810000.0
# Image saved as w_at_iteration_140.png
# Iteration 140 completed in 18s
# Start of iteration 141
# Current loss value: 2724580400.0
# Image saved as w_at_iteration_141.png
# Iteration 141 completed in 18s
# Start of iteration 142
# Current loss value: 2723477000.0
# Image saved as w_at_iteration_142.png
# Iteration 142 completed in 18s
# Start of iteration 143
# Current loss value: 2722224000.0
# Image saved as w_at_iteration_143.png
# Iteration 143 completed in 18s
# Start of iteration 144
# Current loss value: 2720984000.0
# Image saved as w_at_iteration_144.png
# Iteration 144 completed in 18s
# Start of iteration 145
# Current loss value: 2719818000.0
# Image saved as w_at_iteration_145.png
# Iteration 145 completed in 18s
# Start of iteration 146
# Current loss value: 2718623000.0
# Image saved as w_at_iteration_146.png
# Iteration 146 completed in 18s
# Start of iteration 147
# Current loss value: 2717482500.0
# Image saved as w_at_iteration_147.png
# Iteration 147 completed in 18s
# Start of iteration 148
# Current loss value: 2716229600.0
# Image saved as w_at_iteration_148.png
# Iteration 148 completed in 18s
# Start of iteration 149
# Current loss value: 2715015700.0
# Image saved as w_at_iteration_149.png
# Iteration 149 completed in 18s
# Start of iteration 150
# Current loss value: 2713937000.0
# Image saved as w_at_iteration_150.png
# Iteration 150 completed in 18s
# Start of iteration 151
# Current loss value: 2712811000.0
# Image saved as w_at_iteration_151.png
# Iteration 151 completed in 18s
# Start of iteration 152
# Current loss value: 2711534800.0
# Image saved as w_at_iteration_152.png
# Iteration 152 completed in 18s
# Start of iteration 153
# Current loss value: 2710108000.0
# Image saved as w_at_iteration_153.png
# Iteration 153 completed in 18s
# Start of iteration 154
# Current loss value: 2709028000.0
# Image saved as w_at_iteration_154.png
# Iteration 154 completed in 18s
# Start of iteration 155
# Current loss value: 2707939000.0
# Image saved as w_at_iteration_155.png
# Iteration 155 completed in 18s
# Start of iteration 156
# Current loss value: 2706965500.0
# Image saved as w_at_iteration_156.png
# Iteration 156 completed in 18s
# Start of iteration 157
# Current loss value: 2705752000.0
# Image saved as w_at_iteration_157.png
# Iteration 157 completed in 18s
# Start of iteration 158
# Current loss value: 2704464400.0
# Image saved as w_at_iteration_158.png
# Iteration 158 completed in 18s
# Start of iteration 159
# Current loss value: 2703450600.0
# Image saved as w_at_iteration_159.png
# Iteration 159 completed in 18s
# Start of iteration 160
# Current loss value: 2702442800.0
# Image saved as w_at_iteration_160.png
# Iteration 160 completed in 18s
# Start of iteration 161
# Current loss value: 2701162200.0
# Image saved as w_at_iteration_161.png
# Iteration 161 completed in 18s
# Start of iteration 162
# Current loss value: 2700077300.0
# Image saved as w_at_iteration_162.png
# Iteration 162 completed in 18s
# Start of iteration 163
# Current loss value: 2699163600.0
# Image saved as w_at_iteration_163.png
# Iteration 163 completed in 18s
# Start of iteration 164
# Current loss value: 2698180600.0
# Image saved as w_at_iteration_164.png
# Iteration 164 completed in 18s
# Start of iteration 165
# Current loss value: 2697137000.0
# Image saved as w_at_iteration_165.png
# Iteration 165 completed in 18s
# Start of iteration 166
# Current loss value: 2696093700.0
# Image saved as w_at_iteration_166.png
# Iteration 166 completed in 18s
# Start of iteration 167
# Current loss value: 2695165000.0
# Image saved as w_at_iteration_167.png
# Iteration 167 completed in 18s
# Start of iteration 168
# Current loss value: 2694148600.0
# Image saved as w_at_iteration_168.png
# Iteration 168 completed in 18s
# Start of iteration 169
# Current loss value: 2693028000.0
# Image saved as w_at_iteration_169.png
# Iteration 169 completed in 18s
# Start of iteration 170
# Current loss value: 2692200000.0
# Image saved as w_at_iteration_170.png
# Iteration 170 completed in 18s
# Start of iteration 171
# Current loss value: 2691242000.0
# Image saved as w_at_iteration_171.png
# Iteration 171 completed in 18s
# Start of iteration 172
# Current loss value: 2690422800.0
# Image saved as w_at_iteration_172.png
# Iteration 172 completed in 19s
# Start of iteration 173
# Current loss value: 2689601500.0
# Image saved as w_at_iteration_173.png
# Iteration 173 completed in 18s
# Start of iteration 174
# Current loss value: 2688521700.0
# Image saved as w_at_iteration_174.png
# Iteration 174 completed in 18s
# Start of iteration 175
# Current loss value: 2687584000.0
# Image saved as w_at_iteration_175.png
# Iteration 175 completed in 18s
# Start of iteration 176
# Current loss value: 2686608100.0
# Image saved as w_at_iteration_176.png
# Iteration 176 completed in 18s
# Start of iteration 177
# Current loss value: 2685686800.0
# Image saved as w_at_iteration_177.png
# Iteration 177 completed in 18s
# Start of iteration 178
# Current loss value: 2684870000.0
# Image saved as w_at_iteration_178.png
# Iteration 178 completed in 18s
# Start of iteration 179
# Current loss value: 2683821800.0
# Image saved as w_at_iteration_179.png
# Iteration 179 completed in 18s
# Start of iteration 180
# Current loss value: 2682914300.0
# Image saved as w_at_iteration_180.png
# Iteration 180 completed in 18s
# Start of iteration 181
# Current loss value: 2682081500.0
# Image saved as w_at_iteration_181.png
# Iteration 181 completed in 18s
# Start of iteration 182
# Current loss value: 2681201700.0
# Image saved as w_at_iteration_182.png
# Iteration 182 completed in 18s
# Start of iteration 183
# Current loss value: 2680342800.0
# Image saved as w_at_iteration_183.png
# Iteration 183 completed in 18s
# Start of iteration 184
# Current loss value: 2679412500.0
# Image saved as w_at_iteration_184.png
# Iteration 184 completed in 18s
# Start of iteration 185
# Current loss value: 2678646000.0
# Image saved as w_at_iteration_185.png
# Iteration 185 completed in 18s
# Start of iteration 186
# Current loss value: 2677817300.0
# Image saved as w_at_iteration_186.png
# Iteration 186 completed in 18s
# ...
# Image saved as qp_at_iteration_70.png
# Iteration 70 completed in 9s
# Start of iteration 71
# Current loss value: 754574850.0
# Image saved as qp_at_iteration_71.png
# Iteration 71 completed in 9s
# Start of iteration 72
# Current loss value: 753751700.0
# Image saved as qp_at_iteration_72.png
# Iteration 72 completed in 9s
# Start of iteration 73
# Current loss value: 752978240.0
# Image saved as qp_at_iteration_73.png
# Iteration 73 completed in 9s
# Start of iteration 74
# Current loss value: 752248600.0
# Image saved as qp_at_iteration_74.png
# Iteration 74 completed in 9s
# Start of iteration 75
# Current loss value: 751538900.0
# Image saved as qp_at_iteration_75.png
# Iteration 75 completed in 9s
# Start of iteration 76
# Current loss value: 750915460.0
# Image saved as qp_at_iteration_76.png
# Iteration 76 completed in 9s
# Start of iteration 77
# Current loss value: 750331400.0
# Image saved as qp_at_iteration_77.png
# Iteration 77 completed in 9s
# Start of iteration 78
# Current loss value: 749755300.0
# Image saved as qp_at_iteration_78.png
# Iteration 78 completed in 9s
# Start of iteration 79
# Current loss value: 749185300.0
# Image saved as qp_at_iteration_79.png
# Iteration 79 completed in 9s
# Start of iteration 80
# Current loss value: 748541060.0
# Image saved as qp_at_iteration_80.png
# Iteration 80 completed in 9s
# Start of iteration 81
# Current loss value: 747967740.0
# Image saved as qp_at_iteration_81.png
# Iteration 81 completed in 9s
# Start of iteration 82
# Current loss value: 747464060.0
# Image saved as qp_at_iteration_82.png
# Iteration 82 completed in 9s
# Start of iteration 83
# Current loss value: 747009800.0
# Image saved as qp_at_iteration_83.png
# Iteration 83 completed in 9s
# Start of iteration 84
# Current loss value: 746472600.0
# Image saved as qp_at_iteration_84.png
# Iteration 84 completed in 9s
# Start of iteration 85
# Current loss value: 745950600.0
# Image saved as qp_at_iteration_85.png
# Iteration 85 completed in 9s
# Start of iteration 86
# Current loss value: 745426000.0
# Image saved as qp_at_iteration_86.png
# Iteration 86 completed in 9s
# Start of iteration 87
# Current loss value: 744946370.0
# Image saved as qp_at_iteration_87.png
# Iteration 87 completed in 9s
# Start of iteration 88
# Current loss value: 744475400.0
# Image saved as qp_at_iteration_88.png
# Iteration 88 completed in 9s
# Start of iteration 89
# Current loss value: 743887100.0
# Image saved as qp_at_iteration_89.png
# Iteration 89 completed in 9s
# Start of iteration 90
# Current loss value: 743326100.0
# Image saved as qp_at_iteration_90.png
# Iteration 90 completed in 9s
# Start of iteration 91
# Current loss value: 742879000.0
# Image saved as qp_at_iteration_91.png
# Iteration 91 completed in 9s
# Start of iteration 92
# Current loss value: 742364400.0
# Image saved as qp_at_iteration_92.png
# Iteration 92 completed in 9s
# Start of iteration 93
# Current loss value: 741921300.0
# Image saved as qp_at_iteration_93.png
# Iteration 93 completed in 9s
# Start of iteration 94
# Current loss value: 741448770.0
# Image saved as qp_at_iteration_94.png
# Iteration 94 completed in 9s
# Start of iteration 95
# Current loss value: 740983360.0
# Image saved as qp_at_iteration_95.png
# Iteration 95 completed in 9s
# Start of iteration 96
# Current loss value: 740532300.0
# Image saved as qp_at_iteration_96.png
# Iteration 96 completed in 9s
# Start of iteration 97
# Current loss value: 740108400.0
# Image saved as qp_at_iteration_97.png
# Iteration 97 completed in 9s
# Start of iteration 98
# Current loss value: 739662200.0
# Image saved as qp_at_iteration_98.png
# Iteration 98 completed in 9s
# Start of iteration 99
# Current loss value: 739176600.0
# Image saved as qp_at_iteration_99.png
# Iteration 99 completed in 9s
# Start of iteration 100
# Current loss value: 738776700.0
# Image saved as qp_at_iteration_100.png
# Iteration 100 completed in 9s
# Start of iteration 101
# Current loss value: 738363700.0
# Image saved as qp_at_iteration_101.png
# Iteration 101 completed in 9s
# Start of iteration 102
# Current loss value: 737925250.0
# Image saved as qp_at_iteration_102.png
# Iteration 102 completed in 9s
# Start of iteration 103
# Current loss value: 737527740.0
# Image saved as qp_at_iteration_103.png
# Iteration 103 completed in 9s
# Start of iteration 104
# Current loss value: 737133600.0
# Image saved as qp_at_iteration_104.png
# Iteration 104 completed in 9s
# Start of iteration 105
# Current loss value: 736753340.0
# Image saved as qp_at_iteration_105.png
# Iteration 105 completed in 9s
# Start of iteration 106
# Current loss value: 736382400.0
# Image saved as qp_at_iteration_106.png
# Iteration 106 completed in 9s
# Start of iteration 107
# Current loss value: 736027600.0
# Image saved as qp_at_iteration_107.png
# Iteration 107 completed in 9s
# Start of iteration 108
# Current loss value: 735633540.0
# Image saved as qp_at_iteration_108.png
# Iteration 108 completed in 9s
# Start of iteration 109
# Current loss value: 735234300.0
# Image saved as qp_at_iteration_109.png
# Iteration 109 completed in 9s
# Start of iteration 110
# Current loss value: 734842500.0
# Image saved as qp_at_iteration_110.png
# Iteration 110 completed in 9s
# Start of iteration 111
# Current loss value: 734412400.0
# Image saved as qp_at_iteration_111.png
# Iteration 111 completed in 9s
# Start of iteration 112
# Current loss value: 734047040.0
# Image saved as qp_at_iteration_112.png
# Iteration 112 completed in 9s
# Start of iteration 113
# Current loss value: 733654900.0
# Image saved as qp_at_iteration_113.png
# Iteration 113 completed in 9s
# Start of iteration 114
# Current loss value: 733318850.0
# Image saved as qp_at_iteration_114.png
# Iteration 114 completed in 9s
# Start of iteration 115
# Current loss value: 733004740.0
# Image saved as qp_at_iteration_115.png
# Iteration 115 completed in 9s
# Start of iteration 116
# Current loss value: 732670000.0
# Image saved as qp_at_iteration_116.png
# Iteration 116 completed in 9s
# Start of iteration 117
# Current loss value: 732362500.0
# Image saved as qp_at_iteration_117.png
# Iteration 117 completed in 9s
# Start of iteration 118
# Current loss value: 732045440.0
# Image saved as qp_at_iteration_118.png
# Iteration 118 completed in 9s
# Start of iteration 119
# Current loss value: 731738940.0
# Image saved as qp_at_iteration_119.png
# Iteration 119 completed in 9s
# Start of iteration 120
# Current loss value: 731427260.0
# Image saved as qp_at_iteration_120.png
# Iteration 120 completed in 9s
# Start of iteration 121
# Current loss value: 731130430.0
# Image saved as qp_at_iteration_121.png
# Iteration 121 completed in 9s
# Start of iteration 122
# Current loss value: 730819700.0
# Image saved as qp_at_iteration_122.png
# Iteration 122 completed in 9s
# Start of iteration 123
# Current loss value: 730526400.0
# Image saved as qp_at_iteration_123.png
# Iteration 123 completed in 9s
# Start of iteration 124
# Current loss value: 730200300.0
# Image saved as qp_at_iteration_124.png
# Iteration 124 completed in 9s
# Start of iteration 125
# Current loss value: 729914600.0
# Image saved as qp_at_iteration_125.png
# Iteration 125 completed in 9s
# Start of iteration 126
# Current loss value: 729581300.0
# Image saved as qp_at_iteration_126.png
# Iteration 126 completed in 9s
# Start of iteration 127
# Current loss value: 729259140.0
# Image saved as qp_at_iteration_127.png
# Iteration 127 completed in 9s
# Start of iteration 128
# Current loss value: 728969600.0
# Image saved as qp_at_iteration_128.png
# Iteration 128 completed in 9s
# Start of iteration 129
# Current loss value: 728674700.0
# Image saved as qp_at_iteration_129.png
# Iteration 129 completed in 9s
# Start of iteration 130
# Current loss value: 728379400.0
# Image saved as qp_at_iteration_130.png
# Iteration 130 completed in 9s
# Start of iteration 131
# Current loss value: 728057000.0
# Image saved as qp_at_iteration_131.png
# Iteration 131 completed in 9s
# Start of iteration 132
# Current loss value: 727768450.0
# Image saved as qp_at_iteration_132.png
# Iteration 132 completed in 9s
# Start of iteration 133
# Current loss value: 727492500.0
# Image saved as qp_at_iteration_133.png
# Iteration 133 completed in 9s
# Start of iteration 134
# Current loss value: 727198100.0
# Image saved as qp_at_iteration_134.png
# Iteration 134 completed in 9s
# Start of iteration 135
# Current loss value: 726863360.0
# Image saved as qp_at_iteration_135.png
# Iteration 135 completed in 9s
# Start of iteration 136
# Current loss value: 726617340.0
# Image saved as qp_at_iteration_136.png
# Iteration 136 completed in 9s
# Start of iteration 137
# Current loss value: 726363650.0
# Image saved as qp_at_iteration_137.png
# Iteration 137 completed in 9s
# Start of iteration 138
# Current loss value: 726119550.0
# Image saved as qp_at_iteration_138.png
# Iteration 138 completed in 9s
# Start of iteration 139
# Current loss value: 725859460.0
# Image saved as qp_at_iteration_139.png
# Iteration 139 completed in 9s
# Start of iteration 140
# Current loss value: 725600640.0
# Image saved as qp_at_iteration_140.png
# Iteration 140 completed in 9s
# Start of iteration 141
# Current loss value: 725357500.0
# Image saved as qp_at_iteration_141.png
# Iteration 141 completed in 9s
# Start of iteration 142
# Current loss value: 725107140.0
# Image saved as qp_at_iteration_142.png
# Iteration 142 completed in 9s
# Start of iteration 143
# Current loss value: 724842750.0
# Image saved as qp_at_iteration_143.png
# Iteration 143 completed in 9s
# Start of iteration 144
# Current loss value: 724613100.0
# Image saved as qp_at_iteration_144.png
# Iteration 144 completed in 9s
# Start of iteration 145
# Current loss value: 724355500.0
# Image saved as qp_at_iteration_145.png
# Iteration 145 completed in 9s
# Start of iteration 146
# Current loss value: 724113800.0
# Image saved as qp_at_iteration_146.png
# Iteration 146 completed in 9s
# Start of iteration 147
# Current loss value: 723882400.0
# Image saved as qp_at_iteration_147.png
# Iteration 147 completed in 9s
# Start of iteration 148
# Current loss value: 723655200.0
# Image saved as qp_at_iteration_148.png
# Iteration 148 completed in 9s
# Start of iteration 149
# Current loss value: 723420800.0
# Image saved as qp_at_iteration_149.png
# Iteration 149 completed in 9s
# Start of iteration 150
# Current loss value: 723177100.0
# Image saved as qp_at_iteration_150.png
# Iteration 150 completed in 9s
# Start of iteration 151
# Current loss value: 722956000.0
# Image saved as qp_at_iteration_151.png
# Iteration 151 completed in 9s
# Start of iteration 152
# Current loss value: 722740100.0
# Image saved as qp_at_iteration_152.png
# Iteration 152 completed in 9s
# Start of iteration 153
# Current loss value: 722514900.0
# Image saved as qp_at_iteration_153.png
# Iteration 153 completed in 9s
# Start of iteration 154
# Current loss value: 722269900.0
# Image saved as qp_at_iteration_154.png
# Iteration 154 completed in 9s
# Start of iteration 155
# Current loss value: 722048000.0
# Image saved as qp_at_iteration_155.png
# Iteration 155 completed in 9s
# Start of iteration 156
# Current loss value: 721810400.0
# Image saved as qp_at_iteration_156.png
# Iteration 156 completed in 9s
# Start of iteration 157
# Current loss value: 721605440.0
# Image saved as qp_at_iteration_157.png
# Iteration 157 completed in 9s
# Start of iteration 158
# Current loss value: 721365250.0
# Image saved as qp_at_iteration_158.png
# Iteration 158 completed in 9s
# Start of iteration 159
# Current loss value: 721138300.0
# Image saved as qp_at_iteration_159.png
# Iteration 159 completed in 9s
# Start of iteration 160
# Current loss value: 720908800.0
# Image saved as qp_at_iteration_160.png
# Iteration 160 completed in 9s
# Start of iteration 161
# Current loss value: 720676600.0
# Image saved as qp_at_iteration_161.png
# Iteration 161 completed in 9s
# Start of iteration 162
# Current loss value: 720466240.0
# Image saved as qp_at_iteration_162.png
# Iteration 162 completed in 9s
# Start of iteration 163
# Current loss value: 720234500.0
# Image saved as qp_at_iteration_163.png
# Iteration 163 completed in 9s
# Start of iteration 164
# Current loss value: 720024450.0
# Image saved as qp_at_iteration_164.png
# Iteration 164 completed in 9s
# Start of iteration 165
# Current loss value: 719772300.0
# Image saved as qp_at_iteration_165.png
# Iteration 165 completed in 9s
# Start of iteration 166
# Current loss value: 719562500.0
# Image saved as qp_at_iteration_166.png
# Iteration 166 completed in 9s
# Start of iteration 167
# Current loss value: 719356300.0
# Image saved as qp_at_iteration_167.png
# Iteration 167 completed in 9s
# Start of iteration 168
# Current loss value: 719165440.0
# Image saved as qp_at_iteration_168.png
# Iteration 168 completed in 9s
# Start of iteration 169
# Current loss value: 718960500.0
# Image saved as qp_at_iteration_169.png
# Iteration 169 completed in 9s
# Start of iteration 170
# Current loss value: 718765000.0
# Image saved as qp_at_iteration_170.png
# Iteration 170 completed in 9s
# Start of iteration 171
# Current loss value: 718550100.0
# Image saved as qp_at_iteration_171.png
# Iteration 171 completed in 9s
# Start of iteration 172
# Current loss value: 718345340.0
# Image saved as qp_at_iteration_172.png
# Iteration 172 completed in 9s
# Start of iteration 173
# Current loss value: 718144200.0
# Image saved as qp_at_iteration_173.png
# Iteration 173 completed in 9s
# Start of iteration 174
# Current loss value: 717941500.0
# Image saved as qp_at_iteration_174.png
# Iteration 174 completed in 9s
# Start of iteration 175
# Current loss value: 717751040.0
# Image saved as qp_at_iteration_175.png
# Iteration 175 completed in 9s
# Start of iteration 176
# Current loss value: 717549700.0
# Image saved as qp_at_iteration_176.png
# Iteration 176 completed in 9s
# Start of iteration 177
# Current loss value: 717331600.0
# Image saved as qp_at_iteration_177.png
# Iteration 177 completed in 9s
# Start of iteration 178
# Current loss value: 717115100.0
# Image saved as qp_at_iteration_178.png
# Iteration 178 completed in 9s
# Start of iteration 179
# Current loss value: 716903040.0
# Image saved as qp_at_iteration_179.png
# Iteration 179 completed in 9s
# Start of iteration 180
# Current loss value: 716688260.0
# Image saved as qp_at_iteration_180.png
# Iteration 180 completed in 9s
# Start of iteration 181
# Current loss value: 716497150.0
# Image saved as qp_at_iteration_181.png
# Iteration 181 completed in 9s
# Start of iteration 182
# Current loss value: 716294140.0
# Image saved as qp_at_iteration_182.png
# Iteration 182 completed in 9s
# Start of iteration 183
# Current loss value: 716119200.0
# Image saved as qp_at_iteration_183.png
# Iteration 183 completed in 9s
# Start of iteration 184
# Current loss value: 715942800.0
# Image saved as qp_at_iteration_184.png
# Iteration 184 completed in 9s
# Start of iteration 185
# Current loss value: 715768060.0
# Image saved as qp_at_iteration_185.png
# Iteration 185 completed in 9s
# Start of iteration 186
# Current loss value: 715591740.0
# Image saved as qp_at_iteration_186.png
# Iteration 186 completed in 9s
# Start of iteration 187
# Current loss value: 715421060.0
# Image saved as qp_at_iteration_187.png
# Iteration 187 completed in 9s
# Start of iteration 188
# Current loss value: 715243650.0
# Image saved as qp_at_iteration_188.png
# Iteration 188 completed in 9s
# Start of iteration 189
# Current loss value: 715051800.0
# Image saved as qp_at_iteration_189.png
# Iteration 189 completed in 9s
# Start of iteration 190
# Current loss value: 714850000.0
# Image saved as qp_at_iteration_190.png
# Iteration 190 completed in 9s
# Start of iteration 191
# Current loss value: 714693500.0
# Image saved as qp_at_iteration_191.png
# Iteration 191 completed in 9s
# Start of iteration 192
# Current loss value: 714521200.0
# Image saved as qp_at_iteration_192.png
# Iteration 192 completed in 9s
# Start of iteration 193
# Current loss value: 714353000.0
# Image saved as qp_at_iteration_193.png
# Iteration 193 completed in 9s
# Start of iteration 194
# Current loss value: 714169200.0
# Image saved as qp_at_iteration_194.png
# Iteration 194 completed in 9s
# Start of iteration 195
# Current loss value: 713990300.0
# Image saved as qp_at_iteration_195.png
# Iteration 195 completed in 9s
# Start of iteration 196
# Current loss value: 713815000.0
# Image saved as qp_at_iteration_196.png
# Iteration 196 completed in 9s
# Start of iteration 197
# Current loss value: 713620350.0
# Image saved as qp_at_iteration_197.png
# Iteration 197 completed in 9s
# Start of iteration 198
# Current loss value: 713445900.0
# Image saved as qp_at_iteration_198.png
# Iteration 198 completed in 9s
# Start of iteration 199
# Current loss value: 713256960.0
# Image saved as qp_at_iteration_199.png
# Iteration 199 completed in 9s
